# %% [markdown]
# Add user into the database (run on server side)

# %%
import sys
sys.path.append('./src')

# %%
from http_proxy import create_user

# %%
create_user('admin3', 'Goldfish_', './src/config/users.json')
# Out:
# "User 'admin3' created successfully"
