# %% [markdown]
# Add user into the database (run on server side)

# %%
from src.config_utils import create_user

# %%
create_user('admin2', 'Goldfish', './src/config/users.json')
# Out:
# "User 'admin2' created successfully"
